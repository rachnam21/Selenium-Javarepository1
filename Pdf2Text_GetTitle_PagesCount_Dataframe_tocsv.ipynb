# %% [markdown]
# <a href="https://colab.research.google.com/github/rachnam21/Selenium-Javarepository1/blob/master/Pdf2Text_GetTitle_PagesCount_Dataframe_tocsv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdf2text
# Out:
# ...
#      |████████████████████████████████| 4.2MB 2.8MB/s
# ...
#      |████████████████████████████████| 13.7MB 315kB/s
# ...
#   Created wheel for pdf2text: filename=pdf2text-1.0.0-cp36-none-any.whl size=2754 sha256=f629fa97c33c7e9d3462ab940013cdd7eb782d1ba6379357242e52f8ac8d80f9
#   Stored in directory: /root/.cache/pip/wheels/d3/78/cf/8551a9ca700258566709d8f29c9ca4ea071ef36da0cfa36eb1
# ...
#   Created wheel for PDFMiner: filename=pdfminer-20191125-cp36-none-any.whl size=6140077 sha256=157adc0909b2bd35200db362215fc305e46efd12836e8fd417f15ddc9eb0ab2f
#   Stored in directory: /root/.cache/pip/wheels/e1/00/af/720a55d74ba3615bb4709a3ded6dd71dc5370a586a0ff6f326
# Successfully built pdf2text PDFMiner
# ...

# %%
# !pip install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 81kB 2.2MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp36-none-any.whl size=61086 sha256=a20df3d96d35f5743c8b7f0a49be4a9e8d316bb85b650a1b26c82f0abc41642c
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# ...

# %%
import PyPDF2

# %%
pdfFileObject = open(r"Python.pdf", 'rb')

# %%
pdfReader = PyPDF2.PdfFileReader(pdfFileObject)

# %%
print(" No. Of Pages :", pdfReader.numPages)
# Out:
#  No. Of Pages : 87

# %%
pageObject = pdfReader.getPage(5)

# %%
page1 = pageObject.extractText()

# %%
page1
# Out:
# '       The Python Interpreter\n¥Interactive interface to Python\n % python\nPython 2.5 (r25:51908, May 25 2007, 16:14:04) \n[GCC 4.1.2 20061115 (prerelease) (SUSE Linux)] on linux2\nType "help", "copyright", "credits" or "license" for more information.\n>>> ¥Python interpreter evaluates inputs:\n >>> \n3*(7+2)\n 27\n¥Python prompts with Ô>>>Õ. \n¥To exit Python:\n¥CTRL-D\nMonday, October 19, 2009'

# %%
page1a = page1.split('\n \n')

# %%
page2a = page1.split('\n')

# %%
page2a
# Out:
# ['       The Python Interpreter',
#  '¥Interactive interface to Python',
#  ' % python',
#  'Python 2.5 (r25:51908, May 25 2007, 16:14:04) ',
#  '[GCC 4.1.2 20061115 (prerelease) (SUSE Linux)] on linux2',
#  'Type "help", "copyright", "credits" or "license" for more information.',
#  '>>> ¥Python interpreter evaluates inputs:',
#  ' >>> ',
#  '3*(7+2)',
#  ' 27',
#  '¥Python prompts with Ô>>>Õ. ',
#  '¥To exit Python:',
#  '¥CTRL-D',
#  'Monday, October 19, 2009']

# %%
lst = page2a

# %%
print(pageObject.extractText())
# Out:
# Introduction to Python
# Heavily based on presentations by
#     Matt Huenerfauth (Penn State)
#     Guido van Rossum (Google)
#     Richard P. Muller (Caltech)
#     ...Monday, October 19, 2009

# %%
# !pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.4-py2.py3-none-any.whl size=13431 sha256=0437af56c3f85d5d81fc4362956c253066a0b5489e357c7af524fb6af03e49d4
#   Stored in directory: /root/.cache/pip/wheels/63/2a/a0/7596d2e0a73cf0aeffd6f6170862c4e73f3763b7827e48691a
# Successfully built pytesseract
# ...

# %%
# !pip install pandas

# %%
import pandas as pd
from pandas import DataFrame
import pytesseract as pt

# %%
print(os.getcwd())
# Out:
# /content

# %%
# Calling DataFrame constructor on list
df = pd.DataFrame(lst)
print(df)
# Out:
#                                     0
# 0              Introduction to Python
# 1  Heavily based on presentations by
# 2       Matt Huenerfauth (Penn State)
# 3          Guido van Rossum (Google)
# 4         Richard P. Muller (Caltech)
# 5         ...Monday, October 19, 2009

# %%
##LOOPS
pdfReader = PyPDF2.PdfFileReader(pdfFileObject)
print(" No. Of Pages :", pdfReader.numPages)

for i in range(pdfReader.numPages):
  pageObject = pdfReader.getPage(i)
  pageTxt = pageObject.extractText()
  pageOut = pageTxt.split('\n')
  lst.append(pageOut)
  
lst
# Out:
#  No. Of Pages : 87
# ['       File I/O, Strings, Exceptions...',
#  "fileptr = open(ÔfilenameÕ)somestring = fileptr.read()for line in fileptr:   print linefileptr.close()>>> a = 1>>> b = 2.4>>> c = 'Tom'>>> '%s has %d coins worth a total of $%.02f' % (c, a, b)'Tom has 1 coins worth a total of $2.40'>>> try:...     1 / 0... except:...     print('That was silly!')... finally:...     print('This gets executed no matter what')... That was silly!This gets executed no matter whatMonday, October 19, 2009",
#  ['Introduction to Python',
#   'Heavily based on presentations by ',
#   '    Matt Huenerfauth (Penn State)',
#   '    Guido van Rossum (Google) ',
#   '    Richard P. Muller (Caltech)',
#   '    ...Monday, October 19, 2009'],
#  ['       ¥Open source general-purpose language.',
#   '¥Object Oriented, Procedural, Functional',
#   '¥Easy to interface with C/ObjC/Java/Fortran',
#   '¥Easy-ish to interface with C++ (via SWIG)',
#   '¥Great interactive environment',
#   '¥Downloads: ',
# ...

# %%
# Calling DataFrame constructor on list
df = pd.DataFrame(lst)
print(df)
# Out:
#                                                      0
# 0                     File I/O, Strings, Exceptions...
# 1    fileptr = open(ÔfilenameÕ)somestring = fileptr...
# 2    [Introduction to Python, Heavily based on pres...
# 3    [       ¥Open source general-purpose language....
# 4    [       2.5.x / 2.6.x / 3.x ???¥ÒCurrentÓ vers...
# ..                                                 ...
# 171  [       Overloading           class qm_molecul...
# 172  [       Adding to Parent Functions, ¥Sometimes...
# 173  [       Public and Private Data, ¥In Python an...
# 174   [The Extra Stuff..., 86Monday, October 19, 2009]
# 175  [       File I/O, Strings, Exceptions..., file...
#
# [176 rows x 1 columns]

# %%
df.to_csv(r'D:\Rachna\export_dataframe.csv', index = False, header=True)

print (df)
# Out:
#                                                      0
# 0                     File I/O, Strings, Exceptions...
# 1    fileptr = open(ÔfilenameÕ)somestring = fileptr...
# 2    [Introduction to Python, Heavily based on pres...
# 3    [       ¥Open source general-purpose language....
# 4    [       2.5.x / 2.6.x / 3.x ???¥ÒCurrentÓ vers...
# ..                                                 ...
# 171  [       Overloading           class qm_molecul...
# 172  [       Adding to Parent Functions, ¥Sometimes...
# 173  [       Public and Private Data, ¥In Python an...
# 174   [The Extra Stuff..., 86Monday, October 19, 2009]
# 175  [       File I/O, Strings, Exceptions..., file...
#
# [176 rows x 1 columns]

# %%
# Load your PDF
with open('D:/Rachna/Python.pdf', "rb") as f:
    pdf = pdf2text.PDF(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-4de958af7ebb> in <module>()
#       1 # Load your PDF
# ----> 2 with open('D://Rachna//Python.pdf', "rb") as f:
#       3     pdf = pdf2text.PDF(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D://Rachna//Python.pdf'

# %%
import os
THIS_FOLDER = os.path.dirname(os.path.abspath('Python.pdf'))
my_file = os.path.join(THIS_FOLDER, 'Python.pdf')

# %%
# !pip install pdfminer.six
# Out:
# ...
#      |████████████████████████████████| 5.6MB 2.6MB/s
# ...

# %%
from pdfminer.high_level import extract_text
 
text = extract_text("Python.pdf")
 
print(text)
# Out:
# Introduction to Python
#
# Heavily based on presentations by
#     Matt Huenerfauth (Penn State)
#     Guido van Rossum (Google)
#     Richard P. Muller (Caltech)
#     ...
#
# Monday, October 19, 2009
#
# Python
#
# • Open source general-purpose language.
# • Object Oriented, Procedural, Functional
# • Easy to interface with C/ObjC/Java/Fortran
# • Easy-ish to interface with C++ (via SWIG)
# • Great interactive environment
#
# • Downloads: http://www.python.org
# • Documentation: http://www.python.org/doc/
# • Free book: http://www.diveintopython.org
#
# Monday, October 19, 2009
#
#
#
# 2.5.x / 2.6.x / 3.x ???
#
# • “Current” version is 2.6.x
# • “Mainstream” version is 2.5.x
# • The new kid on the block is 3.x
#
# You probably want 2.5.x unless you are starting from
# scratch. Then maybe 3.x
#
# Monday, October 19, 2009
#
#
#
# Technical Issues
#
# Installing & Running Python
#
# Monday, October 19, 2009
#
# Binaries
#
# Linux.
#
# • Python comes pre-installed with Mac OS X and
#
# ...

# %%
# extract text from the first 10 pages
text10 = extract_text("Python.pdf", page_numbers = range(10))

# %%
# !pip install pypdf2
# Out:
# ...
#      |████████████████████████████████| 81kB 2.2MB/s
# ...
#   Created wheel for pypdf2: filename=PyPDF2-1.26.0-cp36-none-any.whl size=61086 sha256=0f4a7cfefe0067272e91778873256eaa6743a3fe38ebca876952583b92b35256
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built pypdf2
# ...

# %%
import PyPDF2

# %%
from PyPDF2 import PdfFileReader
##Capure Title of PDF file
def extract_information(pdf_path):
    with open(pdf_path, 'rb') as f:
        pdf = PdfFileReader(f)
        information = pdf.getDocumentInfo()
        number_of_pages = pdf.getNumPages()

    txt = f"""
    Information about {pdf_path}: 

    Author: {information.author}
    Creator: {information.creator}
    Producer: {information.producer}
    Subject: {information.subject}
    Title: {information.title}
    Number of pages: {number_of_pages}
    """

    print(txt)
    return information

if __name__ == '__main__':
    path = 'Python.pdf'
    extract_information(path)
# Out:
#     Information about Python.pdf:
#
#     Author: None
#     Creator: None
#     Producer: None
#     Subject: None
#     Title: None
#     Number of pages: 87

# %%
# !pip install nltk

# %%
# !pip install numpy

# %%
import nltk
from nltk import tokenize
import numpy as np

# %%
# !pip install pdfminer.six

# %%
import io
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfpage import PDFPage
def extract_text_from_pdf(pdf_path):
    resource_manager = PDFResourceManager()
    fake_file_handle = io.StringIO()
    converter = TextConverter(resource_manager, fake_file_handle)
    page_interpreter = PDFPageInterpreter(resource_manager, converter)
    with open(pdf_path, 'rb') as fh:
        for page in PDFPage.get_pages(fh, 
                                      caching=True,
                                      check_extractable=True):
            page_interpreter.process_page(page)
        text = fake_file_handle.getvalue()
    # close open handles
    converter.close()
    fake_file_handle.close()
    if text:
        return text
if __name__ == '__main__':
    print(extract_text_from_pdf('Python.pdf'))
# Out:
# Introduction to PythonHeavily based on presentations by     Matt Huenerfauth (Penn State)    Guido van Rossum (Google)     Richard P. Muller (Caltech)    ...Monday, October 19, 2009       •Open source general-purpose language.•Object Oriented, Procedural, Functional•Easy to interface with C/ObjC/Java/Fortran•Easy-ish to interface with C++ (via SWIG)•Great interactive environment•Downloads: http://www.python.org•Documentation: http://www.python.org/doc/•Free book: http://www.diveintopython.orgPythonMonday, October 19, 2009       2.5.x / 2.6.x / 3.x ???•“Current” version is 2.6.x•“Mainstream” version is 2.5.x•The new kid on the block is 3.xYou probably want 2.5.x unless you are starting from scratch. Then maybe 3.xMonday, October 19, 2009Technical IssuesInstalling & Running PythonMonday, October 19, 2009       Binaries•Python comes pre-installed with Mac OS X and Linux.•Windows binaries from http://python.org/•You might not have to do anything!Monday, October 19, 2009       The Python 
# ...

# %%
# !pip install pandas
